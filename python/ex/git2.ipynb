# %%
t=6,7,8
type(t)
# Out:
# tuple

# %%
s={}
type(s)
# Out:
# dict

# %%
# how to remove duplicates
l=[19,0,88,7,7]
a=set(l)
a
# Out:
# {0, 7, 19, 88}

# %%
b={55.87,6,'b',776666,(2,3)}
b
# Out:
# {(2, 3), 55.87, 6, 776666, 'b'}

# %%
b=[55.87,6,'b',776666,(2,3)]
b
# Out:
# [55.87, 6, 'b', 776666, (2, 3)]

# %%
s={99,9,0}
s.update([7,8,6])
s
# Out:
# {0, 6, 7, 8, 9, 99}

# %%
s={99,9,0}
s.add((7,8,6))
s
# Out:
# {(7, 8, 6), 0, 9, 99}

# %%
# i want to delete value
s={4,8,9}
s.remove(9)
s
# Out:
# {4, 8}

# %%
s={4,8,9}
s.discard(4)
s
# Out:
# {8, 9}

# %%
s={9,7,988,5,4}
s.pop()
s
# Out:
# {5, 7, 9, 988}

# %%
l=[7,8,80,90]
l.pop()
# Out:
# 90
